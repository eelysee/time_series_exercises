# %%
import requests
import pandas as pd

# %% [markdown]
# ### 1. Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.

# %%
sw_connect = requests.get('https://swapi.dev/api')

# %%
sw_connect.text[:]
# Out:
# '{"people":"https://swapi.dev/api/people/","planets":"https://swapi.dev/api/planets/","films":"https://swapi.dev/api/films/","species":"https://swapi.dev/api/species/","vehicles":"https://swapi.dev/api/vehicles/","starships":"https://swapi.dev/api/starships/"}'

# %%
sw_connect
# Out:
# <Response [200]>

# %%
sw_web = sw_connect.json()

# %%
sw_people = requests.get(sw_web['people']).json()

# %%
sw_people
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
#people = pd.DataFrame(sw_people['results'])

# %%
#people.head(2)

# %%
turn = requests.get(sw_people['next']).json()

# %%
# turn

# %%
# test = pd.concat([people, page_two], ignore_index=True)

# %%
# current = 'https://swapi.dev/api/people/?page=2'

# %%
# response = requests.get(current)

# %%
#requests.get(current)
# Out:
# <Response [200]>

# %%
#response.status_code == 200
# Out:
# True

# %%
#people df

# %%
# this code creats the connection and assigns root
root = requests.get('https://swapi.dev/api/')

# %%
# Checking the api contents of root
root.text
# Out:
# '{"people":"https://swapi.dev/api/people/","planets":"https://swapi.dev/api/planets/","films":"https://swapi.dev/api/films/","species":"https://swapi.dev/api/species/","vehicles":"https://swapi.dev/api/vehicles/","starships":"https://swapi.dev/api/starships/"}'

# %%
# accessing root as a Json so that it can be used and referenced as a python dictionary
root.json()
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %%
# creates a new dictionary by using the value of the people key in the root dictionary. Which is a url.
people = requests.get(root.json()['people']).json()

# %%
# shows results of the people page as a dictionary
# can be verifyed by visiting https://swapi.dev/api/people/
people
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
people['next']
# Out:
# 'https://swapi.dev/api/people/?page=2'

# %%
requests.get(people['next']).json()['results']
# Out:
# [{'name': 'Anakin Skywalker',
#   'height': '188',
#   'mass': '84',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '41.9BBY',
#   'gender': 'male',
#   'homeworld': 'https://swapi.dev/api/planets/1/',
#   'films': ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['https://swapi.dev/api/vehicles/44/',
#    'https://swapi.dev/api/vehicles/46/'],
#   'starships': ['https://swapi.dev/api/starships/39/',
#    'https://swapi.dev/api/starships/59/',
#    'https://swapi.dev/api/starships/65/'],
#   'created': '2014-12-10T16:20:44.310000Z',
#   'edited': '2014-12-20T21:17:50.327000Z',
#   'url': 'https://swapi.dev/api/people/11/'},
#  {'name': 'Wilhuff Tarkin',
#   'height': '180',
#   'mass': 'unknown',
#   'hair_color': 'auburn, grey',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '64BBY',
#   'gender': 'male',
# ...

# %%
people_df = pd.DataFrame(people['results'])

# %%
people_df.head(2)
# Out:
#              name height mass hair_color skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond       fair      blue      19BBY
# 1           C-3PO    167   75        n/a       gold    yellow     112BBY
#
#   gender                         homeworld  \
# 0   male  https://swapi.dev/api/planets/1/
# 1    n/a  https://swapi.dev/api/planets/1/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
#
#                               species  \
# 0                                  []
# 1  [https://swapi.dev/api/species/2/]
#
#                                             vehicles  \
# 0  [https://swapi.dev/api/vehicles/14/, https://s...
# 1                                                 []
#
#                                            starships  \
# 0  [https://swapi.dev/api/starships/12/, https://...
# ...

# %%
root = requests.get('https://swapi.dev/api/')
people = requests.get(root.json()['people']).json()
people_df = pd.DataFrame(people['results'])

# %%
while next_page
